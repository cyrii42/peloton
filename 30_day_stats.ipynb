# %%
from pprint import pprint
import pandas as pd
import plotly.express as px
from datetime import date, datetime, timedelta
from zoneinfo import ZoneInfo
from peloton import PelotonProcessor

EASTERN_TIME = ZoneInfo('America/New_York')
peloton_processor = PelotonProcessor()
# Out:
# Getting workouts from MongoDB...
# Creating processed Dataframe...

# %%
peloton_processor.chart_maker.make_stats_summary(end_date=datetime.now(tz=EASTERN_TIME) - timedelta(days=0))
# Out:
# {'total_workouts': 15,
#  'total_workout_days': 15,
#  'total_duration': 26705,
#  'total_duration_str': '7 hr 25 min',
#  'total_hours': 7.418055555555555,
#  'total_calories': 7378,
#  'total_strive_score': 979.4,
#  'active_weekly_streak': 78}

# %%
peloton_processor.chart_maker.get_achievements()
# Out:
#                                    id                         name  \
# 0    5298b832e2274ad59cf8857240440fb2                 3-Day Streak
# 1    3690014c6baf467899728657c9278e07              The Annual 2024
# 2    013f0b69303d414ca2d73d1aacc04a0e                 5-Day Streak
# 3    5298b832e2274ad59cf8857240440fb2                 3-Day Streak
# 4    bc34e09d3a214293ae5b0042c45b6981  February Activity Challenge
# ..                                ...                          ...
# 188  bac5aefabb2940ba8f0a170fc9d63bf0                  Best Output
# 189  bac5aefabb2940ba8f0a170fc9d63bf0                  Best Output
# 190  5298b832e2274ad59cf8857240440fb2                 3-Day Streak
# 191  5298b832e2274ad59cf8857240440fb2                 3-Day Streak
# 192  bac5aefabb2940ba8f0a170fc9d63bf0                  Best Output
#
#                                  slug  \
# 0                        3_day_streak
# 1                  the_annual_2024_1k
# 2                        5_day_streak
# ...
