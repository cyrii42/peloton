# %%
from pprint import pprint
import pandas as pd
import plotly.express as px
from datetime import date, datetime, timedelta
from zoneinfo import ZoneInfo
from peloton import PelotonProcessor

EASTERN_TIME = ZoneInfo('America/New_York')
peloton_processor = PelotonProcessor()
# Out:
# Getting workouts from MongoDB...
# Creating processed Dataframe...

# %%
peloton_processor.chart_maker.make_stats_summary(end_date=datetime.now(tz=EASTERN_TIME))
# Out:
# {'total_workouts': 19,
#  'total_workout_days': 19,
#  'total_duration': 25800,
#  'total_duration_str': '7 hr 10 min',
#  'total_hours': 7.166666666666667,
#  'total_calories': 7139,
#  'total_strive_score': 935.3,
#  'active_weekly_streak': 84}

# %%
peloton_processor.chart_maker.get_achievements().tail(30)
# Out:
#                                    id                      name  \
# 171  5298b832e2274ad59cf8857240440fb2              3-Day Streak
# 172  657e50c747d6458480f1ba6a0fa94c6a               Dynamic Duo
# 173  fa5a37ee99ec49febff3232dbc27dc5b   March Cycling Challenge
# 174  f637f8638fe7408d80c86fd73de41d1c  March Activity Challenge
# 175  5298b832e2274ad59cf8857240440fb2              3-Day Streak
# 176  5298b832e2274ad59cf8857240440fb2              3-Day Streak
# 177  5298b832e2274ad59cf8857240440fb2              3-Day Streak
# 178  4087c9245a804b1585b878a0337972e4   April Cycling Challenge
# 179  5298b832e2274ad59cf8857240440fb2              3-Day Streak
# 180  4c9788b952374fdca19352c3b4fde177  April Activity Challenge
# 181  b1e56850e3d04b618b146882d80e5083   April Cycling Challenge
# 182  57519706808847ee8eeacb64029a6ea3  April Activity Challenge
# 183  fe6d044cd09742a0b779148a5fd10919       Peloton Scenic 2021
# 184  8c828ed03d8746be9393948a5e8c8656            70-Week Streak
# ...
